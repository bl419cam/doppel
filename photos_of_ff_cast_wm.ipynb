# %% [markdown]
# ![](https://images.unsplash.com/photo-1551557479-80682eb12a86?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=1650&q=80)

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport fast_and_furious

# %% [markdown]
# ## Libraries

# %%
import fast_and_furious as ff
from google_images_download import google_images_download   #importing the library

# %% [markdown]
# ## Search Terms

# %%
# Check list
search_terms = ff.lindy_list
search_terms = search_terms[:3]
search_terms
# Out:
# ['agent markham fast and furious',
#  'orange julius fast and furious',
#  'slap jack fast and furious']

# %% [markdown]
# ## Search!!!!

# %%
response = google_images_download.googleimagesdownload()   #class instantiation

# %%
for term in search_terms:
    arguments = {"keywords":term
                 ,"limit":200
              #   ,"offset":100
                 ,'type':'face'
                 ,"print_urls":True
                 ,"chromedriver":"./drivers/chromedriver"
                }   #creating list of arguments
    paths = response.download(arguments)   #passing the arguments to the function
    print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = agent markham fast and furious
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/en/thumb/f/f4/Rupert_Gwynne.jpg/221px-Rupert_Gwynne.jpg
# Completed Image ====> 1.221px-Rupert_Gwynne.jpg
# Image URL: https://vignette.wikia.nocookie.net/fastandfurious/images/a/a7/Markham.jpg/revision/latest?cb=20131012001509
# Invalid or missing image format. Skipping...
# Image URL: https://vignette.wikia.nocookie.net/fastandfurious/images/b/b9/Agent_Dunn_-_2F2F.png/revision/latest?cb=20160119093248
# Invalid or missing image format. Skipping...
# Image URL: https://vignette.wikia.nocookie.net/fastandfurious/images/2/2b/Agent_Markham_-_2F2F.png/revision/latest?cb=20160119093523
# Invalid or missing image format. Skipping...
# Image URL: https://c8.alamy.com/comp/BR57BF/james-remar-2-fast-2-furious-the-fast-and-the-furious-2-2003-BR57BF.jpg
# ...

# %%
# Test on just one
# arguments = {"keywords":'agent markham fast and furious',"limit":20,"print_urls":True}   #creating list of arguments
# paths = response.download(arguments)   #passing the arguments to the function
# print(paths)   #printing absolute paths of the downloaded images
